# %% [markdown]
# ### 유튜브 페이지에 접속해서 원하는 검색어를 입력 후 검색된 페이지 내에서 조건에 맞는 수집시스템 구축

# %%
# !pip install selenium
# !pip install -U selenium

# 웹드라이버를 자동으로 관리하고 업데이트 해주는 파이썬 라이브러리
# !pip install webdriver_manager
# Out:
# Requirement already satisfied: selenium in c:\users\smhrd\anaconda3\lib\site-packages (4.18.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: outcome in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\smhrd\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\smhrd\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\smhrd\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\smhrd\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.9.0)
# Requirement already satisfied: selenium in c:\users\smhrd\anaconda3\lib\site-packages (4.18.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\smhrd\anaconda3\lib\site-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: outcome in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\smhrd\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\smhrd\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\smhrd\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\smhrd\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\smhrd\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.9.0)
# Requirement already satisfied: webdriver_manager in c:\users\smhrd\anaconda3\lib\site-packages (4.0.1)
# Requirement already satisfied: requests in c:\users\smhrd\anaconda3\lib\site-packages (from webdriver_manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\smhrd\anaconda3\lib\site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\smhrd\anaconda3\lib\site-packages (from webdriver_manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smhrd\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smhrd\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smhrd\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smhrd\anaconda3\lib\site-packages (from requests->webdriver_manager) (2023.7.22)

# %%
import pandas as pd

from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup as bs

from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.support.ui import WebDriverWait
# WebDriverWait : 특정 조건이 충족될 때까지 기다리는데 사용하는 모듈
from selenium.webdriver.support import expected_conditions as EC
# EC : WebDriverWait가 기다리는 조건을 정의하는데 사용하는 모듈

# %%
s = Service(ChromeDriverManager().install())
driver = wb.Chrome(service=s)

# %%
# 유튜브 검색 키워드 입력
keyword = input('유튜브 검색어를 입력하세요 >> ')
url = f'https://www.youtube.com/results?search_query={keyword}'
driver.get(url)
# Out:
# 유튜브 검색어를 입력하세요 >> 띱

# %%
names = driver.find_elements(By.CSS_SELECTOR, 'yt-formatted-string.style-scope.ytd-video-renderer')
for i in names:
    print(i.text)
    
# 유튜브 제목만 출력된게 아니다!
# 페이지를 잘 살펴보면, class값을 여러 태그들이 지니고 있다
# -> 다른 방법을 사용해야 하겠다
# Out:
# 너 그거 들었어?
#
#
# 띱 #뒷담화 #스케치코미디 뒷담화 선입견 니트남 / 윤혁준 - https://www.instagram.com/yhjune/ 여 / 김규남 ...
# 서프라이즈
#
#
# 띱 #여친선물 #스케치코미디 서프라이즈 여동생 / 김규남 - https://www.instagram.com/knamiiiiii/ 오빠 / 윤태용 ...
# 맛집 촬영
#
#
# 단기알바 맛집 촬영 세상 맛있는 칼칼함의 탄생, 노랑통닭 칼칼한 청양 치킨! 여러분도 한번 드셔보실래요? 홈페이지 링크: ...
# 고독정식
#
#
# 띱 #나는솔로 #스케치코미디 고독정식 영철 / 윤태용 - https://www.instagram.com/actor_y16/ 영호 / 윤혁준 ...
# 진짜 안 먹어
#
#
# 띱 #다이어트 #스케치코미디 야식 메이트의 다이어트 재도전 장소협찬 : 헬스장 - 바르지 (서울 마포구 성미산로6길 45) 고깃집 - 성미 ...
# 손님과 알바
#
#
# 띱 #써브웨이 #썹픽 #스케치코미디 손님과 알바 정말 간편하고 빠르고 순식간에 주문이 끝나버렸다.. 써브웨이 베스트 조합으로 ...
# 수도권 집값 바닥락.. 절망 사회로 가는 길목에서...우리는
#
#
# 우리 은행 ( 대동 포럼 ) 박 홍기 후원 계좌 1005 - 203 - 205878 대동 포럼 소액 후원을 환영하며 10 만원 이상은 정중하게 사절 합니다.
# 사내 체육대회
#
#
# 직장인 체육대회 #띱 #코믹숏무비 #스케치코미디 반팔남 / 윤혁준 - https://www.instagram.com/yhjune/ 여 / 김규남 ...
# D-61
#
#
# 수능 고3 #띱 #코믹숏무비 #스케치코미디 오빠 / 윤태용 - https://www.instagram.com/actor_y16/ 고3 / 김규남 ...
# 내가 우습니?
#
#
# 꼰대 #띱 #코믹숏무비 #스케치코미디 선배 / 김규남 - https://www.instagram.com/knamiiiiii/ 연출 / 윤태용 ...
# 동심지킴단
#
#
# 띱 #크리스마스 #스케치코미디 동심지킴단 엄마 / 김규남 - https://www.instagram.com/knamiiiiii/ 아빠 / 윤혁준 ...
# 어릴 때 크게 다친 적이 있네?
#
#
# 사주카페 #띱 #코믹숏무비 #스케치코미디 남자손님 / 윤태용 - https://www.instagram.com/actor_y16/ 여자손님 / 김규남 ...
# E 와 I 더블데이트
#
#
# 띱 #플러팅 #스케치코미디 E와 I의 더블데이트 단발 여 / 김규남 - https://www.instagram.com/knamiiiiii/ 긴머리 여 / 구금비 ...
# 진 사람이 치우기
#
#
# 띱 #내기 #스케치코미디 가위바위보 회색옷 / 윤태용 - https://www.instagram.com/actor_y16/ 여 / 김규남 ...
# 연말 보내기
#
#
# 띱 #연말 #스케치코미디 외향인과 내향인의 연말 E / 윤태용 - https://www.instagram.com/actor_y16/ I / 김규남 ...
# 안 갚는 친구
#
#
# 띱 #돈 #스케치코미디 돈 안 갚는 친구 바람막이 남 / 윤혁준 - https://www.instagram.com/yhjune/ 후드티 남 / 윤태용 ...
# 나 있는 거 모르나?
#
#
# 커플 싸움 #띱 #코믹숏무비 #스케치코미디 남자 / 윤태용 - https://www.instagram.com/actor_y16/ 여자 / 김규남 ...
# 연애 몰아보기
#
#
# 띱 #연애 #스케치코미디 연애 몰아보기 윤태용 - https://www.instagram.com/actor_y16/ 김규남 ...
# 그놈이 왔다
#
#
# 띱 #겨울 #스케치코미디 겨울 보일러 여 / 김규남 - https://www.instagram.com/knamiiiiii/ 오빠 / 윤태용 ...
# 친구 몰아보기
#
#
# 띱 #친구 #스케치코미디 친구 몰아보기 윤태용 - https://www.instagram.com/actor_y16/ 김규남 ...
# 저 사람 어때
#
#
# 띱 #헌팅 #스케치코미디 #롯데칠성 #KRUSH #헌팅 좀 새롭고.. 쿨한 느낌? 보자마자 crush on 해버릴지도 모를 KRUSH! 아 엣지!
# 쟤야?
#
#
# 띱 #전여친 #스케치코미디 전여친 여 / 김규남 - https://www.instagram.com/knamiiiiii/ 남 / 윤혁준 ...
# 봐도 돼?
#
#
# 띱 #인스타 #스케치코미디 남친 SNS 남 / 윤태용 - https://www.instagram.com/actor_y16/ 여 / 김규남 ...
# 소개팅만 하면 친구가 돼
#
#
# 띱 #소개팅 #스케치코미디 소개팅 하면 친구가 되는 사람 남 / 윤태용 - https://www.instagram.com/actor_y16/ 여 / 김규남 ...

# %%
# a태그에 감싸져 있다 -> a태그와 클래스까지 활용

# %%
# url 수집
# 같은 id를 가진 a태그가 여러개 존재한다? --> id가 지금 class처럼 사용됨
video_url = driver.find_elements(By.CSS_SELECTOR, "a#video-title")
# 유튜브에 있는 영상 하나하나가 전부 다른 서버에 존재하기 때문에
for i in video_url:
    print(i.get_attribute('href'))
# Out:
# https://www.youtube.com/watch?v=ybv8TTkoWBQ&pp=ygUD652x
# https://www.youtube.com/watch?v=MzM4bjU_BH8&pp=ygUD652x
# https://www.youtube.com/watch?v=hG7ygb5ebTI&pp=ygUD652x
# https://www.youtube.com/watch?v=sw64M0w4HO0&pp=ygUD652x
# https://www.youtube.com/watch?v=MOM9jdBKtYk&pp=ygUD652x
# https://www.youtube.com/watch?v=F8f_Tobdu6o&pp=ygUD652x
# https://www.youtube.com/watch?v=PRhtz1_9QU4&pp=ygUD652x
# https://www.youtube.com/watch?v=9rSSIRsQAQc&pp=ygUD652x
# https://www.youtube.com/watch?v=4xGqiqC5J6E&pp=ygUD652x
# https://www.youtube.com/watch?v=d_a6xE1R5oc&pp=ygUD652x
# https://www.youtube.com/watch?v=u53wvlB4gAI&pp=ygUD652x
# https://www.youtube.com/watch?v=bwaJ6HFWrOI&pp=ygUD652x
# https://www.youtube.com/watch?v=qwaYZdRzjcE&pp=ygUD652x
# https://www.youtube.com/watch?v=AnKxBDFV1BA&pp=ygUD652x
# https://www.youtube.com/watch?v=WCefYiyVu3s&pp=ygUD652x
# https://www.youtube.com/watch?v=CzaVwwGkqDw&pp=ygUD652x
# https://www.youtube.com/watch?v=1ulNPjElP_Y&pp=ygUD652x
# https://www.youtube.com/watch?v=ASE1DcKgLak&pp=ygUD652x
# https://www.youtube.com/watch?v=OjokJ0Czl-s&pp=ygUD652x
# https://www.youtube.com/watch?v=S_Nfn35yIFQ&pp=ygUD652x
# https://www.youtube.com/watch?v=fDITxRnR2-E&pp=ygUD652x
# https://www.youtube.com/watch?v=g1tuEI-hLhU&pp=ygUD652x
# https://www.youtube.com/watch?v=dm0sBStOgMo&pp=ygUD652x
# https://www.youtube.com/watch?v=bxDLfizVXDI&pp=ygUD652x

# %%
len(names), len(video_url)
# names랑 video_url의 길이가 다르다 -> 수집 방법에 차이가 존재!
# Out:
# (96, 24)

# %%
names = driver.find_elements(By.CSS_SELECTOR, "a#video-title>yt-formatted-string")
for i in names:
    print(i.text)
# Out:
# 너 그거 들었어?
# 서프라이즈
# 맛집 촬영
# 고독정식
# 진짜 안 먹어
# 손님과 알바
# 수도권 집값 바닥락.. 절망 사회로 가는 길목에서...우리는
# 사내 체육대회
# D-61
# 내가 우습니?
# 동심지킴단
# 어릴 때 크게 다친 적이 있네?
# E 와 I 더블데이트
# 진 사람이 치우기
# 연말 보내기
# 안 갚는 친구
# 나 있는 거 모르나?
# 연애 몰아보기
# 그놈이 왔다
# 친구 몰아보기
# 저 사람 어때
# 쟤야?
# 봐도 돼?
# 소개팅만 하면 친구가 돼

# %%
len(names), len(video_url)
# Out:
# (24, 24)

# %%
n_lst=[]
u_lst=[]
# 반복문 사용해서 이름,url을 리스트에 집어넣기

for n in names: # 유튜브 영상 제목
    n_lst.append(n.text)
    
for u in video_url: # 유튜브 영상 링크(url)
    u_lst.append(u.get_attribute('href'))

u_lst
# Out:
# ['https://www.youtube.com/watch?v=ybv8TTkoWBQ&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=MzM4bjU_BH8&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=hG7ygb5ebTI&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=sw64M0w4HO0&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=MOM9jdBKtYk&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=F8f_Tobdu6o&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=PRhtz1_9QU4&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=9rSSIRsQAQc&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=4xGqiqC5J6E&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=d_a6xE1R5oc&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=u53wvlB4gAI&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=bwaJ6HFWrOI&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=qwaYZdRzjcE&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=AnKxBDFV1BA&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=WCefYiyVu3s&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=CzaVwwGkqDw&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=1ulNPjElP_Y&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=ASE1DcKgLak&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=OjokJ0Czl-s&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=S_Nfn35yIFQ&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=fDITxRnR2-E&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=g1tuEI-hLhU&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=dm0sBStOgMo&pp=ygUD652x',
#  'https://www.youtube.com/watch?v=bxDLfizVXDI&pp=ygUD652x']

# %%
# 영상의 제목과 링크가 너무 길다 -> 컬럼의 너비 제한 없애기
pd.set_option('display.max_colwidth', None)

# %%
dic = {'영상이름': n_lst, '링크':u_lst}
y_df = pd.DataFrame(dic)
y_df
# Out:
#                                  영상이름  \
# 0                           너 그거 들었어?
# 1                               서프라이즈
# 2                               맛집 촬영
# 3                                고독정식
# 4                             진짜 안 먹어
# 5                              손님과 알바
# 6   수도권 집값 바닥락.. 절망 사회로 가는 길목에서...우리는
# 7                             사내 체육대회
# 8                                D-61
# 9                             내가 우습니?
# 10                              동심지킴단
# 11                  어릴 때 크게 다친 적이 있네?
# 12                        E 와 I 더블데이트
# 13                          진 사람이 치우기
# 14                             연말 보내기
# 15                            안 갚는 친구
# 16                        나 있는 거 모르나?
# 17                            연애 몰아보기
# 18                             그놈이 왔다
# 19                            친구 몰아보기
# 20                            저 사람 어때
# 21                                쟤야?
# 22                              봐도 돼?
# 23                      소개팅만 하면 친구가 돼
#
#                                                          링크
# 0   https://www.youtube.com/watch?v=ybv8TTkoWBQ&pp=ygUD652x
# 1   https://www.youtube.com/watch?v=MzM4bjU_BH8&pp=ygUD652x
# 2   https://www.youtube.com/watch?v=hG7ygb5ebTI&pp=ygUD652x
# 3   https://www.youtube.com/watch?v=sw64M0w4HO0&pp=ygUD652x
# 4   https://www.youtube.com/watch?v=MOM9jdBKtYk&pp=ygUD652x
# 5   https://www.youtube.com/watch?v=F8f_Tobdu6o&pp=ygUD652x
# 6   https://www.youtube.com/watch?v=PRhtz1_9QU4&pp=ygUD652x
# 7   https://www.youtube.com/watch?v=9rSSIRsQAQc&pp=ygUD652x
# 8   https://www.youtube.com/watch?v=4xGqiqC5J6E&pp=ygUD652x
# 9   https://www.youtube.com/watch?v=d_a6xE1R5oc&pp=ygUD652x
# 10  https://www.youtube.com/watch?v=u53wvlB4gAI&pp=ygUD652x
# 11  https://www.youtube.com/watch?v=bwaJ6HFWrOI&pp=ygUD652x
# 12  https://www.youtube.com/watch?v=qwaYZdRzjcE&pp=ygUD652x
# 13  https://www.youtube.com/watch?v=AnKxBDFV1BA&pp=ygUD652x
# 14  https://www.youtube.com/watch?v=WCefYiyVu3s&pp=ygUD652x
# 15  https://www.youtube.com/watch?v=CzaVwwGkqDw&pp=ygUD652x
# 16  https://www.youtube.com/watch?v=1ulNPjElP_Y&pp=ygUD652x
# 17  https://www.youtube.com/watch?v=ASE1DcKgLak&pp=ygUD652x
# 18  https://www.youtube.com/watch?v=OjokJ0Czl-s&pp=ygUD652x
# 19  https://www.youtube.com/watch?v=S_Nfn35yIFQ&pp=ygUD652x
# 20  https://www.youtube.com/watch?v=fDITxRnR2-E&pp=ygUD652x
# 21  https://www.youtube.com/watch?v=g1tuEI-hLhU&pp=ygUD652x
# 22  https://www.youtube.com/watch?v=dm0sBStOgMo&pp=ygUD652x
# 23  https://www.youtube.com/watch?v=bxDLfizVXDI&pp=ygUD652x

# %%
driver.quit()

# %% [markdown]
# ### 워드클라우드

# %%
y_df.to_csv('유튜브데이터.csv')

# %%
f = open('유튜브데이터.csv', 'r', encoding='utf-8')
data=f.read()
f.close()

print(data)
# Out:
# ,영상이름,링크
# 0,너 그거 들었어?,https://www.youtube.com/watch?v=ybv8TTkoWBQ&pp=ygUD652x
# 1,서프라이즈,https://www.youtube.com/watch?v=MzM4bjU_BH8&pp=ygUD652x
# 2,맛집 촬영,https://www.youtube.com/watch?v=hG7ygb5ebTI&pp=ygUD652x
# 3,고독정식,https://www.youtube.com/watch?v=sw64M0w4HO0&pp=ygUD652x
# 4,진짜 안 먹어,https://www.youtube.com/watch?v=MOM9jdBKtYk&pp=ygUD652x
# 5,손님과 알바,https://www.youtube.com/watch?v=F8f_Tobdu6o&pp=ygUD652x
# 6,수도권 집값 바닥락.. 절망 사회로 가는 길목에서...우리는,https://www.youtube.com/watch?v=PRhtz1_9QU4&pp=ygUD652x
# 7,사내 체육대회,https://www.youtube.com/watch?v=9rSSIRsQAQc&pp=ygUD652x
# 8,D-61,https://www.youtube.com/watch?v=4xGqiqC5J6E&pp=ygUD652x
# 9,내가 우습니?,https://www.youtube.com/watch?v=d_a6xE1R5oc&pp=ygUD652x
# 10,동심지킴단,https://www.youtube.com/watch?v=u53wvlB4gAI&pp=ygUD652x
# 11,어릴 때 크게 다친 적이 있네?,https://www.youtube.com/watch?v=bwaJ6HFWrOI&pp=ygUD652x
# 12,E 와 I 더블데이트,https://www.youtube.com/watch?v=qwaYZdRzjcE&pp=ygUD652x
# 13,진 사람이 치우기,https://www.youtube.com/watch?v=AnKxBDFV1BA&pp=ygUD652x
# 14,연말 보내기,https://www.youtube.com/watch?v=WCefYiyVu3s&pp=ygUD652x
# 15,안 갚는 친구,https://www.youtube.com/watch?v=CzaVwwGkqDw&pp=ygUD652x
# 16,나 있는 거 모르나?,https://www.youtube.com/watch?v=1ulNPjElP_Y&pp=ygUD652x
# 17,연애 몰아보기,https://www.youtube.com/watch?v=ASE1DcKgLak&pp=ygUD652x
# 18,그놈이 왔다,https://www.youtube.com/watch?v=OjokJ0Czl-s&pp=ygUD652x
# 19,친구 몰아보기,https://www.youtube.com/watch?v=S_Nfn35yIFQ&pp=ygUD652x
# 20,저 사람 어때,https://www.youtube.com/watch?v=fDITxRnR2-E&pp=ygUD652x
# 21,쟤야?,https://www.youtube.com/watch?v=g1tuEI-hLhU&pp=ygUD652x
# 22,봐도 돼?,https://www.youtube.com/watch?v=dm0sBStOgMo&pp=ygUD652x
# 23,소개팅만 하면 친구가 돼,https://www.youtube.com/watch?v=bxDLfizVXDI&pp=ygUD652x

# %%
type(data)
# Out:
# str

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\smhrd\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\smhrd\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\smhrd\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\smhrd\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six in c:\users\smhrd\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    ---------------- ----------------------- 122.9/300.2 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Obtaining dependency information for konlpy from https://files.pythonhosted.org/packages/5a/95/896914d9461c12f07e6f8afb1f7462e28395fc46b54fcbb96f1ea3cff8fb/konlpy-0.6.0-py2.py3-none-any.whl.metadata
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Obtaining dependency information for JPype1>=0.7.0 from https://files.pythonhosted.org/packages/1f/19/144f3a767b563ba5c6d4aa534ea1f3fad9a5067c3917df4458a6e1afe0ef/JPype1-1.5.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading JPype1-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\smhrd\anaconda3\lib\site-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in c:\users\smhrd\anaconda3\lib\site-packages (from konlpy) (1.24.3)
# Requirement already satisfied: packaging in c:\users\smhrd\anaconda3\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/19.4 MB 1.3 MB/s eta 0:00:16
#     --------------------------------------- 0.3/19.4 MB 3.4 MB/s eta 0:00:06
#    - -------------------------------------- 0.8/19.4 MB 7.1 MB/s eta 0:00:03
#    --- ------------------------------------ 1.7/19.4 MB 9.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.8/19.4 MB 12.8 MB/s eta 0:00:02
#    -------- ------------------------------- 4.3/19.4 MB 16.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 5.6/19.4 MB 18.0 MB/s eta 0:00:01
#    --------------- ------------------------ 7.7/19.4 MB 21.2 MB/s eta 0:00:01
#    ------------------- -------------------- 9.4/19.4 MB 24.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 11.1/19.4 MB 32.7 MB/s eta 0:00:01
#    -------------------------- ------------- 12.8/19.4 MB 40.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 14.2/19.4 MB 40.9 MB/s eta 0:00:01
#    -------------------------------- ------- 15.9/19.4 MB 43.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 17.4/19.4 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  19.2/19.4 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 28.5 MB/s eta 0:00:00
# Downloading JPype1-1.5.0-cp311-cp311-win_amd64.whl (351 kB)
#    ---------------------------------------- 0.0/351.5 kB ? eta -:--:--
#    --------------------------------------- 351.5/351.5 kB 22.8 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc = WordCloud(font_path='C:\Windows\Fonts\HMFMPYUN.ttf',
              background_color = 'white',
              colormap = 'Dark2').generate(data)
wc.words_
# Out:
# {'https': 1.0,
#  'youtube': 1.0,
#  'watch v': 1.0,
#  'pp ygUD652x': 1.0,
#  '안': 0.08333333333333333,
#  'E': 0.08333333333333333,
#  '친구': 0.08333333333333333,
#  '몰아보기': 0.08333333333333333,
#  '돼': 0.08333333333333333,
#  '영상이름': 0.041666666666666664,
#  '링크': 0.041666666666666664,
#  '너': 0.041666666666666664,
#  '그거': 0.041666666666666664,
#  '들었어': 0.041666666666666664,
#  'ybv8TTkoWBQ': 0.041666666666666664,
#  '서프라이즈': 0.041666666666666664,
#  'MzM4bjU_BH8': 0.041666666666666664,
#  '맛집': 0.041666666666666664,
#  '촬영': 0.041666666666666664,
#  'hG7ygb5ebTI': 0.041666666666666664,
#  '고독정식': 0.041666666666666664,
#  'sw64M0w4HO0': 0.041666666666666664,
#  '진짜': 0.041666666666666664,
#  '먹어': 0.041666666666666664,
#  'MOM9jdBKtYk': 0.041666666666666664,
#  '손님과': 0.041666666666666664,
#  '알바': 0.041666666666666664,
#  'F8f_Tobdu6o': 0.041666666666666664,
#  '수도권': 0.041666666666666664,
#  '집값': 0.041666666666666664,
#  '바닥락': 0.041666666666666664,
#  '절망': 0.041666666666666664,
#  '사회로': 0.041666666666666664,
#  '가는': 0.041666666666666664,
#  '길목에서': 0.041666666666666664,
#  '우리는': 0.041666666666666664,
#  'PRhtz1_9QU4': 0.041666666666666664,
#  '사내': 0.041666666666666664,
#  '체육대회': 0.041666666666666664,
#  '9rSSIRsQAQc': 0.041666666666666664,
#  'D': 0.041666666666666664,
#  '4xGqiqC5J6E': 0.041666666666666664,
#  '내가': 0.041666666666666664,
#  '우습니': 0.041666666666666664,
#  'd_a6xE1R5oc': 0.041666666666666664,
#  '동심지킴단': 0.041666666666666664,
#  'u53wvlB4gAI': 0.041666666666666664,
#  '어릴': 0.041666666666666664,
#  '때': 0.041666666666666664,
#  '크게': 0.041666666666666664,
#  '다친': 0.041666666666666664,
#  '적이': 0.041666666666666664,
#  '있네': 0.041666666666666664,
#  'bwaJ6HFWrOI': 0.041666666666666664,
#  '와': 0.041666666666666664,
#  '더블데이트': 0.041666666666666664,
#  'qwaYZdRzjcE': 0.041666666666666664,
#  '진': 0.041666666666666664,
#  '사람이': 0.041666666666666664,
#  '치우기': 0.041666666666666664,
#  'AnKxBDFV1BA': 0.041666666666666664,
#  '연말': 0.041666666666666664,
#  '보내기': 0.041666666666666664,
#  'WCefYiyVu3s': 0.041666666666666664,
#  '갚는': 0.041666666666666664,
#  'CzaVwwGkqDw': 0.041666666666666664,
#  '나': 0.041666666666666664,
#  '있는': 0.041666666666666664,
#  '거': 0.041666666666666664,
#  '모르나': 0.041666666666666664,
#  '1ulNPjElP_Y': 0.041666666666666664,
#  '연애': 0.041666666666666664,
#  'ASE1DcKgLak': 0.041666666666666664,
#  '그놈이': 0.041666666666666664,
#  '왔다': 0.041666666666666664,
#  'OjokJ0Czl': 0.041666666666666664,
#  's': 0.041666666666666664,
#  'S_Nfn35yIFQ': 0.041666666666666664,
#  '저': 0.041666666666666664,
#  '사람': 0.041666666666666664,
#  '어때': 0.041666666666666664,
#  'fDITxRnR2': 0.041666666666666664,
#  '쟤야': 0.041666666666666664,
#  'g1tuEI': 0.041666666666666664,
#  'hLhU': 0.041666666666666664,
#  '봐도': 0.041666666666666664,
#  'dm0sBStOgMo': 0.041666666666666664,
#  '소개팅만': 0.041666666666666664,
#  '하면': 0.041666666666666664,
#  '친구가': 0.041666666666666664,
#  'bxDLfizVXDI': 0.041666666666666664}

# %%
plt.figure(figsize=(12,5)) # 워드클라우드 크기 설정
plt.axis('off')
plt.imshow(wc)
plt.savefig('./워드클라우드결과.jpg') # 이미지 결과 저장
